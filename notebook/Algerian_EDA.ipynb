# %% [markdown]
# # Algerian Forest Fires Dataset
#
# ##### Data Set Information:
#
# The dataset includes 244 instances that regroup a data of two regions of Algeria, namely thje Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria
#
# 122 instances for each region
#
# The period from June 2012 to September 2012. The dataset includes 11 attributes and 1 output attribute(class). The 244 instances have been classified into fire(138 cases) and not fire (106 classes) classes.

# %% [markdown]
# ##### Attribute Information:
# 1. Date: (DD/MM/YY) Day,month('june' to 'september'), year(2012) Weather data observations
# 2. Temp: temperaturte noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH: Relative Humidity in %: 21 to 90
# 4. WS: Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8 FWI Components
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI): 0 to 31.1
# 12. Classes: two classes;

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Algerian_forest_fires_dataset.csv')

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %% [markdown]
# #### Data Cleaning

# %%
# missing values 
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.drop(122,inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# The dataset is converted into two sets based on Region from 123rd index, we can make a new column based on the Region
#
# 1: "Bejaja Region Dataset"
#
# 2: "Sidi-Bel Abbes Region Dataset"
#
# Add new column with region

# %%
df.reset_index(inplace=True)

# %%
df.loc[:121,"Region"] = 0
df.loc[122:,"Region"] = 1

# %%
df.head()
# Out:
#    index day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  \
# 0      0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1      1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2      2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4      4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9
#
#    FWI    Classes    Region
# 0  0.5  not fire        0.0
# 1  0.4  not fire        0.0
# 2  0.1  not fire        0.0
# 3    0  not fire        0.0
# 4  0.5  not fire        0.0

# %%
df['Region'] = df['Region'].astype(int)

# %%
df.head()
# Out:
#    index day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  \
# 0      0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1      1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2      2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4      4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9
#
#    FWI    Classes    Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3    0  not fire          0
# 4  0.5  not fire          0

# %%
df.isnull().sum()
# Out:
# index          0
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      index                            day month  year Temperature   RH   Ws  \
# 122    123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN
# 167    168                             14     7  2012          37   37   18
#
#     Rain   FFMC   DMC      DC   ISI   BUI      FWI Classes    Region
# 122   NaN   NaN   NaN     NaN   NaN   NaN      NaN       NaN       1
# 167   0.2  88.9  12.9  14.6 9  12.5  10.4  fire          NaN       1

# %%
# Removing null values 
df.drop(122,inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
#      index day month  year Temperature  RH  Ws Rain   FFMC   DMC      DC  \
# 167    168  14     7  2012          37  37  18   0.2  88.9  12.9  14.6 9
#
#       ISI   BUI      FWI Classes    Region
# 167  12.5  10.4  fire          NaN       1

# %%
df.head()
# Out:
#    index day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  \
# 0      0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1      1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2      2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4      4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9
#
#    FWI    Classes    Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3    0  not fire          0
# 4  0.5  not fire          0

# %%
df.value_counts()
# Out:
# index  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC   DC     ISI   BUI   FWI   Classes       Region
# 0      1    6      2012  29           57   18   0      65.7  3.4   7.6    1.3   3.4   0.5   not fire      0         1
# 155    1    7      2012  28           58   18   2.2    63.7  3.2   8.5    1.2   3.3   0.5   not fire      1         1
# 157    3    7      2012  34           56   17   0.1    84.7  9.7   27.3   4.7   10.3  5.2   fire          1         1
# 158    4    7      2012  34           58   18   0      88    13.6  36.8   8     14.1  9.9   fire          1         1
# 159    5    7      2012  34           45   18   0      90.5  18.7  46.4   11.3  18.7  15    fire          1         1
#                                                                                                                    ..
# 85     25   8      2012  35           60   15   0      88.9  43.9  181.3  8.2   54.7  20.3  fire          0         1
# ...

# %%
df.drop(167,inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.drop(columdfns=['index'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.drop(columdfns=['index'],inplace=True)
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'columdfns'. Did you mean 'columns'?

# %%
df.head()
# Out:
#    index day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  \
# 0      0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1      1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2      2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4      4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9
#
#    FWI    Classes    Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3    0  not fire          0
# 4  0.5  not fire          0

# %%
df.isnull().sum()
# Out:
# index          0
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.loc[[122]]
# Out:
#      index  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  \
# 122    124  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC
#
#      ISI  BUI  FWI  Classes    Region
# 122  ISI  BUI  FWI  Classes         1

# %%
df = df.drop(122).reset_index(drop=True)

# %%
df.loc[[122]]
# Out:
#      index day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  \
# 122    125   1     6  2012          32  71  12   0.7  57.1  2.5  8.2  0.6
#
#      BUI  FWI    Classes    Region
# 122  2.8  0.2  not fire          1

# %%
df.columns
# Out:
# Index(['index', 'day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df['Classes'] = df['Classes'].str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        243 non-null    int64
#  1   day          243 non-null    object
#  2   month        243 non-null    object
#  3   year         243 non-null    object
#  4   Temperature  243 non-null    object
#  5   RH           243 non-null    object
#  6   Ws           243 non-null    object
#  7   Rain         243 non-null    object
#  8   FFMC         243 non-null    object
#  9   DMC          243 non-null    object
#  10  DC           243 non-null    object
#  11  ISI          243 non-null    object
#  12  BUI          243 non-null    object
#  13  FWI          243 non-null    object
#  14  Classes      243 non-null    object
#  15  Region       243 non-null    int64
# dtypes: int64(2), object(14)
# memory usage: 30.5+ KB

# %% [markdown]
# #### Change the required columns as integer data type

# %%
df.columns
# Out:
# Index(['index', 'day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df[['month','day','year','Temperature','RH','Ws']] = df[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        243 non-null    int64
#  1   day          243 non-null    int64
#  2   month        243 non-null    int64
#  3   year         243 non-null    int64
#  4   Temperature  243 non-null    int64
#  5   RH           243 non-null    int64
#  6   Ws           243 non-null    int64
#  7   Rain         243 non-null    object
#  8   FFMC         243 non-null    object
#  9   DMC          243 non-null    object
#  10  DC           243 non-null    object
#  11  ISI          243 non-null    object
#  12  BUI          243 non-null    object
#  13  FWI          243 non-null    object
#  14  Classes      243 non-null    object
#  15  Region       243 non-null    int64
# dtypes: int64(8), object(8)
# memory usage: 30.5+ KB

# %%
# Changing other columns to float data dtype 
objects = [features for features in df.columns if df[features].dtypes=='O' and features != "Classes"]

# %%
for i in objects: 
    df[i] = df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        243 non-null    int64
#  1   day          243 non-null    int64
#  2   month        243 non-null    int64
#  3   year         243 non-null    int64
#  4   Temperature  243 non-null    int64
#  5   RH           243 non-null    int64
#  6   Ws           243 non-null    int64
#  7   Rain         243 non-null    float64
#  8   FFMC         243 non-null    float64
#  9   DMC          243 non-null    float64
#  10  DC           243 non-null    float64
#  11  ISI          243 non-null    float64
#  12  BUI          243 non-null    float64
#  13  FWI          243 non-null    float64
#  14  Classes      243 non-null    object
#  15  Region       243 non-null    int64
# dtypes: float64(7), int64(8), object(1)
# memory usage: 30.5+ KB

# %%
df.describe()
# Out:
#             index         day       month    year  Temperature          RH  \
# count  243.000000  243.000000  243.000000   243.0   243.000000  243.000000
# mean   122.814815   15.761317    7.502058  2012.0    32.152263   62.041152
# std     71.976599    8.842552    1.114793     0.0     3.628039   14.828160
# min      0.000000    1.000000    6.000000  2012.0    22.000000   21.000000
# 25%     60.500000    8.000000    7.000000  2012.0    30.000000   52.500000
# 50%    121.000000   16.000000    8.000000  2012.0    32.000000   63.000000
# 75%    185.500000   23.000000    8.000000  2012.0    35.000000   73.500000
# max    246.000000   31.000000    9.000000  2012.0    42.000000   90.000000
#
#                Ws        Rain        FFMC         DMC          DC         ISI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean    15.493827    0.762963   77.842387   14.680658   49.430864    4.742387
# ...

# %%
# save the clean dataset 
df.to_csv('Algerian_forest_fires_cleaned_dataset.csv',index=False)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df_copy = df.drop(columns=['day','month','year'],axis=1)

# %%
df_copy.head()
# Out:
#    index  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI   Classes  \
# 0      0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1      1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2      2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3      3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4      4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_copy.drop(columns=['index'],axis=1,inplace=True)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI   Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire       0

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire        137
# not fire    106
# Name: count, dtype: int64

# %%
# Encoding of the categories in classes 
df_copy['Classes'] = np.where(df_copy['Classes'] == 'not fire',0,1)

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %% [markdown]
# ### Plot density plot for all features

# %%
sns.set_style('darkgrid')

# %%
df_copy.hist(bins=50,figsize=(20,15))
plt.show()

# %%
## Percentage for Pie Chart 
percentage = df_copy['Classes'].value_counts(normalize=True)*100

# %%
# plotting pie chart 
classlabels = ['Fire','Not Fire']
color = ['red','yellow']
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%',colors=color,shadow=True)
plt.title("Pie Chart of Classes")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Classes')

# %%
## Correlation 
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(data=df_copy.corr())
# Out:
# <Axes: >

# %%
# Box plots 
sns.boxplot(df['FWI'],orient='h',color='lightgreen')
# Out:
# <Axes: xlabel='FWI'>

# %%
df.drop('index',axis=1,inplace=True)
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  Region
# 0  0.5  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.0  not fire       0
# 4  0.5  not fire       0

# %%
# Monthly Fire Analysis 
df_temp = df.loc[df['Region'] == 0]
plt.subplots(figsize=(13,6))
sns.set_style("whitegrid")
sns.countplot(x='month',hue='Classes',data=df_temp)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Bejaia Regions",weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire Analysis of Bejaia Regions')

# %%
df_temp = df.loc[df['Region'] == 1]
plt.subplots(figsize=(13,6))
sns.set_style("whitegrid")
sns.countplot(x='month',hue='Classes',data=df_temp)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Sidi-Bel Abbes Regions",weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire Analysis of Sidi-Bel Abbes Regions')

# %% [markdown]
# It's observed that August and September had the most number of forest fires for both regions, and from the above plot of months, we can understand few things:
#
# Most of the fires happened in August and very high fires happened in only 3 months - June, July and August
#
# Less fires was on September
